# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense

from statsmodels.tsa.seasonal import STL

import math
# Out:
# WARNING:tensorflow:From C:\Users\PLEXTEK\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dataframe = pd.read_csv('output2.csv',usecols=[1]).iloc[:8000,:].clip(lower = 0)
dataframe
# Out:
#       Plasma_current
# 0             0.0000
# 1             1.3591
# 2             5.7585
# 3            11.6940
# 4            17.8730
# ...              ...
# 7995          0.0000
# 7996          0.0000
# 7997          0.0000
# 7998          0.0000
# 7999          0.0000
#
# [8000 rows x 1 columns]

# %%
plt.plot(dataframe)

# %%
dataset = dataframe.values
dataset = dataset.astype('float32')
dataset.shape
# Out:
# (8000, 1)

# %% [markdown]
# # Preprocessing

# %%
scaler = MinMaxScaler(feature_range=(0,1))
dataset = scaler.fit_transform(dataframe)

# %%
train_size = int(len(dataset)*0.80)
test_size = len(dataset) - train_size

# %%
traindata = dataset[:train_size,:]
testdata = dataset[train_size:,:]
testdata.shape
# Out:
# (1600, 1)

# %%
time_window , forecasting_term = 10,20

# %%
def to_sequences(dataset,time_window,forecasting_term):
    X = []
    y= []
    
    for i in range(len(dataset) - time_window - forecasting_term):
        X.append(dataset[i:i + time_window,:].reshape(-1,1))
        y.append(dataset[i + time_window:i+ time_window + forecasting_term,:].reshape(-1,1))
        
    return np.array(X),np.array(y)

# %%
trainX, trainY = to_sequences(traindata,time_window,forecasting_term)
trainY.shape
# Out:
# (6370, 20, 1)

# %% [markdown]
# # CRUcell

# %%
hidden=2048

# %%
wx_t = Dense(hidden*3, input_shape=(time_window,1))
wx_s = Dense(hidden*3, input_shape=(time_window,1))
wx_r = Dense(hidden, input_shape=(time_window,1))
# Out:
# WARNING:tensorflow:From C:\Users\PLEXTEK\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
wh_t = Dense(hidden*3, input_shape=(hidden,1))
wh_s = Dense(hidden*3, input_shape=(hidden,1))
wh_r = Dense(hidden, input_shape=(hidden,1))

# %%
hid_state = np.zeros((3, len(traindata)-time_window-forecasting_term, hidden) )
hid_state[0,:,:].shape
# Out:
# (6370, 2048)

# %%
output = []

# %%
output = []
for i in range(time_window):
  
    lamda = 0.5
    x = pd.DataFrame(trainX[ : ,i,: ])
    dates = pd.date_range('1990-01-01', periods = len(x), freq='D')
    x.index = dates
    trend = []
    seasonal = []
    resid = []
    for i in range(len(x.columns)):
        stl = STL(x[i])
        res = stl.fit()
        trend.append(res.trend.values)
        seasonal.append(res.seasonal.values)
        resid.append(res.resid.values)
        
    trend = np.array(trend)
    seasonal = np.array(seasonal)
    resid = np.array(resid)
    
    x_t = tf.transpose(trend, perm=[1, 0])
    x_s = tf.transpose(seasonal, perm=[1, 0])
    x_r = tf.transpose(resid, perm=[1, 0])
        
    x_t = wx_t(x_t)
    x_s = wx_s(x_s)
    x_r = wx_r(x_r)
    
    h_t = wh_t(hid_state[0,:,:])
    h_s = wh_s(hid_state[1,:,:])
    
    x_autocor_t, x_cor_t, x_new_t = tf.split(x_t, num_or_size_splits=3, axis=1)
    x_autocor_s, x_cor_s, x_new_s = tf.split(x_s, num_or_size_splits=3, axis=1)
    h_autocor_t, h_cor_t, h_new_t = tf.split(h_t, num_or_size_splits=3, axis=1)
    h_autocor_s, h_cor_s, h_new_s = tf.split(h_s, num_or_size_splits=3, axis=1)
    
    autocor_t = tf.sigmoid(x_autocor_t + h_autocor_t)
    autocor_s = tf.sigmoid(x_autocor_s + h_autocor_s)
    
    cor_t = tf.sigmoid(x_cor_t + h_cor_s)
    cor_s = tf.sigmoid(x_cor_s + h_cor_t)
    
    new_t = lamda*tf.tanh(x_new_t + (autocor_t * h_new_t)) + (1-lamda)*tf.tanh(x_new_t + (cor_t * h_new_s))
    new_s = lamda*tf.tanh(x_new_s + (autocor_s * h_new_s)) + (1-lamda)*tf.tanh(x_new_s + (cor_s * h_new_t))
    
    hid_state[0,:,:] = new_t
    hid_state[1,:,:] = new_s
    hid_state[2,:,:] = tf.tanh(x_r)
    
    output.append( new_t + new_s + tf.tanh(x_r))

# %%
fc = Sequential([
    tf.keras.layers.Flatten(input_shape=(hidden,)),  # Flatten the input
    tf.keras.layers.Dense(forecasting_term,activation='elu'),  # Dense layer
])

# %%
output = fc(hid_state[-1])
output.shape
# Out:
# TensorShape([6370, 20])

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
trainY = tf.reshape(trainY, [6370,20])

# %%
output = scaler.inverse_transform(output)
trainY = scaler.inverse_transform(output)

# %%
mse = tf.keras.losses.MeanSquaredError()

# Assuming 'm' is a TensorFlow model
para = fc.trainable_variables
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

for e in range(epoch):
    optimizer.zero_grad()
    with tf.GradientTape() as tape:
        out, _ = m(self.trainX)
        loss = crit(out, tf.reshape(self.trainY, (-1, 1)))
    gradients = tape.gradient(loss, para)
    optimizer.apply_gradients(zip(gradients, para))

    # if (e+1) % 2 == 0:
    pred, _ = m(self.testX)
    pred = pred.numpy()
    real = self.testY.numpy().reshape(-1, 1)
    for i in range(len(self.scaler)):
        pred[i, :] = self.scaler[i].inverse_transform(pred[i, :].reshape(-1, 1))
        real[i, :] = self.scaler[i].inverse_transform(real[i, :].reshape(-1, 1))

    test_mape = tf.reduce_mean(tf.abs((pred - real) / pred)) * 100
    test_rmse = mean_squared_error(pred, real) ** 0.5

    print('[Epoch: {}/{}] [Train Loss: {}] [Test RMSE: {}] [Test MAPE: {}]'.format(
        e + 1, epoch, str(loss.numpy())[:6], str(test_rmse)[:6], str(test_mape)[:6]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 7
#       4 para = fc.trainable_variables
#       5 optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
# ----> 7 for e in range(epoch):
#       8     optimizer.zero_grad()
#       9     with tf.GradientTape() as tape:
#
# NameError: name 'epoch' is not defined

# %%
trainScore = math.sqrt(mean_squared_error(output,trainY ))
print('Train Score: %.2f RMSE' % (trainScore))
# Out:
# Train Score: 3730.40 RMSE
